# %% [markdown]
# <center>
# In the name of God
# <br>
# <h3>Computer Programming Course</h3>
#
# <br>
# <img src="./Figures/kntu.png" width="50px" height="50px"/>
# <br>
# K. N. Toosi University of Technology
# <br>
# 1402-1403
# <br>
#
#
# </center>

# %%
# %%js
# let a=String(100+23);
# element.text(a);

# %%
# %%js
# let a=String(100) + "*" +String(23);
# element.text(a);

# %%
# %%js
# let a=eval(String(100) + "-" +String(23));
# element.text(a);

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# %%js
# let x=5;
# x++;
# x+=10;
# x/=2;
# element.text(x);

# %% [markdown]
# %%js
# let x=5
# x++
# x+=10
# element.text(x);

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# %%js
# let x=5;
# x++;
# x+=10;
# element.text(x);

# %%
# %%js
# let carName;
# carName="BMW";
# carName="Benz";
# element.text(carName);

# %%
# %%js
# let r=1;
# const pi=3.14;
# let area=pi*r**2;
# r=14;
# element.text(area);

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# %%js
# let r2=1;
# const pi=3.14;
# let area=pi*r2**2;
# r=14;
# element.text(area);

# %%
# %%js
# let r2=1;
# const pi=3.14;
# let area=pi*r2**2;
# r2=14;
# element.text(area);

# %% [markdown]
# ## Reserved words

# %% [markdown]
# ![image.png](attachment:image.png)
